# %% [markdown]
# # Using pyjack alpha in jupyter
#
# This tutorial will go through the basics of using pyjack

# %%
# Import relevant packages
import pandas as pd
import matplotlib.pyplot as plt
from pyjack21 import BlackJackTable

# %% [markdown]
# ## BlackJackTable
#
# This class simulates hands of blackjack. The results are stored in a pandas dataframe.
#
# In the alpha all players start with 500 and will bet 10 until they lose all of their money
#
# **Optional Parameters:**
# + hands: number of hands to play. Defaults to 1
# + decks: number of decks to put in the shoe. Defaults to 6
# + player_count: number of players at the table. Defaults to 4

# %%
player_count = 6
table = BlackJackTable(hands=2000, decks=6, player_count=player_count)
table.run()
blackjack_data = table.df

# %%
blackjack_data
# Out:
#      dealer_card dealer_hand dealer_final_hand  payroll_0 hand_0 init_move_0  \
# 0            NaN         NaN               NaN      500.0    NaN         NaN
# 1              Q          12                21      515.0     AK   BLACKJACK
# 2              A          20                20      505.0     88           P
# 3              K          12                22      515.0     4J           H
# 4              4           6                24      535.0     29           D
# ...          ...         ...               ...        ...    ...         ...
# 1996           K          20                20     1305.0     78           H
# 1997           9          14                20     1315.0     58           H
# 1998           A          15                19     1325.0     QK           S
# 1999           K          21               NaN     1315.0     39         NaN
# 2000           4          14                19     1330.0     AK   BLACKJACK
#
#       payroll_1 hand_1 init_move_1  payroll_2  ... init_move_2 payroll_3  \
# 0         500.0    NaN         NaN      500.0  ...         NaN     500.0
# 1         490.0     6K           H      490.0  ...           H     490.0
# 2         490.0     A9           S      480.0  ...           H     470.0
# 3         500.0     8Q           S      490.0  ...           S     480.0
# 4         510.0     6K           S      500.0  ...           S     490.0
# ...         ...    ...         ...        ...  ...         ...       ...
# 1996        0.0                NaN     1145.0  ...           H     655.0
# 1997        0.0                NaN     1135.0  ...           H     645.0
# 1998        0.0                NaN     1150.0  ...   BLACKJACK     655.0
# 1999        0.0                NaN     1140.0  ...         NaN     645.0
# 2000        0.0                NaN     1130.0  ...           S     625.0
#
#       hand_3 init_move_3 payroll_4  hand_4 init_move_4 payroll_5  hand_5  \
# 0        NaN         NaN     500.0     NaN         NaN     500.0     NaN
# 1         A5           H     490.0      59           H     490.0      6T
# 2         56           D     480.0      46           S     480.0      8J
# 3         A6           H     490.0      34           H     470.0      24
# 4         5T           S     500.0      77           P     490.0      38
# ...      ...         ...       ...     ...         ...       ...     ...
# 1996      39           H     530.0      77           H     530.0      JK
# 1997      9Q           S     520.0      34           H     520.0      8Q
# 1998      3K           H     520.0      38           H     530.0      6K
# 1999      2J         NaN     510.0      8K         NaN     520.0      45
# 2000      27           D     500.0      6T           S     535.0      AJ
#
#      init_move_5
# 0            NaN
# 1              H
# 2              S
# 3              H
# 4              D
# ...          ...
# 1996           S
# 1997           S
# 1998           H
# 1999         NaN
# 2000   BLACKJACK
#
# [2001 rows x 21 columns]

# %%
for i in range(player_count):
    plt.plot(blackjack_data[f'payroll_{i}'])

# %%
# Calculate the average payroll
blackjack_data['payroll_avg'] = blackjack_data['payroll_0']
for i in range(player_count):
    blackjack_data['payroll_avg'] = blackjack_data['payroll_avg'] + blackjack_data[f'payroll_{i}']
blackjack_data['payroll_avg'] = blackjack_data['payroll_avg'] / player_count


plt.plot(blackjack_data['payroll_avg'])
