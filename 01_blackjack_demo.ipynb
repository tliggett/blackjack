# %%
# Import relevant packages
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import library features
from lib.game import BlackJackTable

# %%
table = BlackJackTable(hands=1000)
table.run()
blackjack_data = table.df

# %%
blackjack_data
# Out:
#      dealer_card dealer_hand dealer_final_hand  payroll_0 hand_0 init_move_0  \
# 0            NaN         NaN               NaN      500.0    NaN         NaN
# 1              J          19                19      490.0     6K           H
# 2              8          17                17      500.0     9K           S
# 3              T          17                17      510.0     A9           S
# 4              Q          19                19      500.0     49           H
# ...          ...         ...               ...        ...    ...         ...
# 996            K          19                19      165.0     A4           H
# 997            2          13                23      175.0     9K           S
# 998            7          13                22      165.0     58           H
# 999            7          10                18      155.0     4K           H
# 1000           9          20                20      145.0     3T           H
#
#       payroll_1 hand_1 init_move_1  payroll_2 hand_2 init_move_2  payroll_3  \
# 0         500.0    NaN         NaN      500.0    NaN         NaN      500.0
# 1         510.0     A9           S      500.0     A2           H      490.0
# 2         500.0     4T           H      510.0     TJ           S      505.0
# 3         510.0     8Q           S      500.0     77           H      515.0
# 4         500.0     69           H      490.0     28           H      505.0
# ...         ...    ...         ...        ...    ...         ...        ...
# 996       200.0     8Q           S       30.0     TQ           S      170.0
# 997       220.0     29           D       40.0     49           S      180.0
# 998       230.0     67           H       50.0     39           H      190.0
# 999       220.0     69           H       60.0     A3           H      180.0
# 1000      210.0     34           H       40.0     56           D      170.0
#
#      hand_3 init_move_3
# 0       NaN         NaN
# 1        4K           H
# 2        AK   BLACKJACK
# 3        78           H
# 4        3T           H
# ...     ...         ...
# 996      A8           S
# 997      5T           S
# 998      88           P
# 999      68           H
# 1000     26           H
#
# [1001 rows x 15 columns]

# %%
for i in range(4):
    plt.plot(blackjack_data[f'payroll_{i}'])
